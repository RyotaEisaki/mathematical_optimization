# %%
# %matplotlib inline
import matplotlib.pyplot as plt, pandas as pd, numpy as np

# %%
plt.rcParams['font.family'] = 'AppleGothic' # フォント指定
df=pd.DataFrame(np.sin(np.linspace(0,np.pi))) # np.linspace(0,np.pi) 等差数列を生成
df.plot(title='サイン')

# %%
df
# Out:
#                0
# 0   0.000000e+00
# 1   6.407022e-02
# 2   1.278772e-01
# 3   1.911586e-01
# 4   2.536546e-01
# 5   3.151082e-01
# 6   3.752670e-01
# 7   4.338837e-01
# 8   4.907176e-01
# 9   5.455349e-01
# 10  5.981105e-01
# 11  6.482284e-01
# 12  6.956826e-01
# 13  7.402780e-01
# 14  7.818315e-01
# 15  8.201723e-01
# 16  8.551428e-01
# 17  8.865993e-01
# 18  9.144126e-01
# 19  9.384684e-01
# 20  9.586679e-01
# 21  9.749279e-01
# 22  9.871818e-01
# 23  9.953791e-01
# 24  9.994862e-01
# 25  9.994862e-01
# 26  9.953791e-01
# 27  9.871818e-01
# 28  9.749279e-01
# 29  9.586679e-01
# 30  9.384684e-01
# 31  9.144126e-01
# 32  8.865993e-01
# 33  8.551428e-01
# 34  8.201723e-01
# 35  7.818315e-01
# 36  7.402780e-01
# 37  6.956826e-01
# 38  6.482284e-01
# 39  5.981105e-01
# 40  5.455349e-01
# 41  4.907176e-01
# 42  4.338837e-01
# 43  3.752670e-01
# 44  3.151082e-01
# 45  2.536546e-01
# 46  1.911586e-01
# 47  1.278772e-01
# 48  6.407022e-02
# 49  1.224647e-16

# %%
pd.DataFrame(np.random.exponential(1,10)).boxplot()
