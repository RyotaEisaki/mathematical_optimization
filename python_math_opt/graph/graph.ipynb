# %%
# %matplotlib inline
import networkx as nx
import matplotlib.pyplot as plt

# %%
G=nx.Graph()
vlist=[1,2,3,4]
elist=[(1,1),(1,1),(2,1),(1,3),(2,3),(2,4),(3,4)]
G.add_nodes_from(vlist)
G.add_edges_from(elist)
nx.draw_networkx(G,node_color='lightgray',node_size=400)
plt.axis('off')
plt.show()

# %%
print('virtex list: ',G.nodes())
print('virtex number: ',G.number_of_nodes())
print('neighbors of virtex 1: ', [v for v in nx.all_neighbors(G,1)])
# Out:
# virtex list:  [1, 2, 3, 4]
# virtex number:  4
# neighbors of virtex 1:  [1, 2, 3]

# %%
DG=nx.DiGraph()
vlist=[1,2,3,4]
elist=[(1,1),(1,1),(2,1),(1,3),(2,3),(2,4),(3,4)]
DG.add_nodes_from(vlist)
DG.add_edges_from(elist)
nx.draw_networkx(DG,node_color='lightgray',node_size=400)
plt.axis('off')
plt.show()

# %%
print('DG edge list: ', DG.edges())
print('DG edge number: ', DG.number_of_edges())
# Out:
# DG edge list:  [(1, 1), (1, 3), (2, 1), (2, 3), (2, 4), (3, 4)]
# DG edge number:  6

# %%
# 隣接行列と接続行列

# %%
G=nx.MultiGraph()
G.add_edges_from([(1,2),(1,3),(3,1),(2,3),(2,2)])
A=nx.adjacency_matrix(G)
M=nx.incidence_matrix(G)
print('A=',A.toarray())
print('M=',M.toarray())
# Out:
# A= [[0 1 2]
#  [1 1 1]
#  [2 1 0]]
# M= [[1. 1. 1. 0. 0.]
#  [1. 0. 0. 1. 0.]
#  [0. 1. 1. 1. 0.]]

# %%
nx.draw_networkx(G,node_color='lightgray',node_size=400)
plt.axis('off')
plt.show()

# %%
G=nx.complete_graph(5) # 完全グラフ
p=nx.spring_layout(G,iterations=50)
nx.draw_networkx(G,pos=p,node_color='lightgrey',node_size=300)
plt.axis('off')
plt.show()

# %%
# 同型であるかをチェックする

# %%
G1=nx.Graph()
G1.add_edges_from([(1,4),(1,5),(1,6),(2,4),(2,5),(2,6),(3,4),(3,5),(4,6)])

G2=nx.Graph()
G2.add_edges_from([('a','b'),('a','d),(1,6),(2,4),(2,5),(2,6),(3,4),(3,5),(4,6)])

G3=nx.Graph()
G3.add_edges_from([(1,4),(1,5),(1,6),(2,4),(2,5),(2,6),(3,4),(3,5),(4,6)])
